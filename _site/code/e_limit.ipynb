# %% [markdown]
# © 2018 Suzy Beeler. This work is licensed under a [Creative Commons Attribution License CC-BY 4.0](https://creativecommons.org/licenses/by/4.0/). All code contained herein is licensed under an [MIT license](https://opensource.org/licenses/MIT)
#
# This exercise was generated from a Jupyter notebook. You can download the notebook [here](e_limit.ipynb).
# ___
#
# # Objective
#
# In this tutorial, we'll gain a little more practice with plotting in Python, by seeing how $\big(1 + \frac{1}{N}\big)^N$ scales with increasing values of $N$.
#
# # Plotting
#
# Before writing any code, we always need to import the packages that we will be using.

# %%
# Import the necessary modules
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# For pretty plots
import seaborn as sns
rc={'lines.linewidth': 2, 'axes.labelsize': 14, 'axes.titlesize': 14, \
    'xtick.labelsize' : 14, 'ytick.labelsize' : 14}
sns.set(rc=rc)

# %% [markdown]
# We first need to specify the values of N we would like to assess. We can do that using `numpy`'s `linspace` function which takes in a starting value, an ending value, and the number of values to be included between these endpoints. We can then use this array of $N$ values to determine the corresponding $y$ values that result from $\big(1 + \frac{1}{N}\big)^N$.

# %%
# values of N to assess, 100 points spaced evenly from 1 to 10
Ns = np.linspace(1,10,100)

# calculate the y values for the Ns 
ys = (1 + 1/Ns)**Ns

# plot Ns vs. ys
plt.plot(Ns, ys)
plt.xlabel('N')
plt.ylabel('$y$')
# Out:
# Text(0,0.5,'$y$')

# %% [markdown]
# We see that $\big(1 + \frac{1}{N}\big)^N$ seems to be approaching some asymptote as $N$ increases. Let's expand the values of $N$ we are looking at to better see what value this seems to be approaching.

# %%
# values of N to assess, 100 points spaced evenly from 1 to 10
Ns = np.linspace(1,100,100)

# calculate the y values for the Ns 
ys = (1 + 1/Ns)**Ns

# plot Ns vs. ys
plt.plot(Ns, ys)
plt.xlabel('N')
plt.ylabel('$y$')
# Out:
# Text(0,0.5,'$y$')

# %% [markdown]
# The asymptote seems to be somewhere around 2.7. Might this be $e$? Let's plot the value of $e$ on the graph as well for comparison.

# %%
# values of N to assess, 100 points spaced evenly from 1 to 10
Ns = np.linspace(1,100,100)

# calculate the y values for the Ns 
ys = (1 + 1/Ns)**Ns

# plot Ns vs. ys
plt.plot(Ns, ys)

# plot the value of e for every N
plt.plot(Ns, [np.e]*len(Ns))

plt.xlabel('N')
plt.ylabel('$y$')
plt.legend(["our function","$e$"])

# %% [markdown]
# From this, we do in fact see that
#
# $$\lim_{N\to\infty} \bigg(1 + \frac{1}{N}\bigg)^N = e.$$
